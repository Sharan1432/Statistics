# %%
"1. Generate a list of 100 integers containing values between 90 to 130 and store it in the variable `int_list`. After generating the list, find the following:"

"a.Generate the List of 100 Integers"

import random

int_list = [random.randint(90, 130) for _ in range(100)]
print("Generated List:", int_list)

"b.Calculate the Mean and Median"

def calculate_mean(numbers):
    return sum(numbers) / len(numbers)

def calculate_median(numbers):
    sorted_numbers = sorted(numbers)
    n = len(sorted_numbers)
    midpoint = n // 2
    if n % 2 == 1:
        return sorted_numbers[midpoint]
    else:
        return (sorted_numbers[midpoint - 1] + sorted_numbers[midpoint]) / 2

mean_value = calculate_mean(int_list)
median_value = calculate_median(int_list)

print("Mean:", mean_value)
print("Median:", median_value)

"c. Compute the Mode"

from collections import Counter

def calculate_mode(numbers):
    frequency = Counter(numbers)
    mode_data = frequency.most_common(1)
    return mode_data[0][0]

mode_value = calculate_mode(int_list)

print("Mode:", mode_value)

"d.Calculate the Weighted Mean"

def calculate_weighted_mean(values, weights):
    weighted_sum = sum(value * weight for value, weight in zip(values, weights))
    total_weight = sum(weights)
    return weighted_sum / total_weight

values = [90, 95, 100, 105, 110]
weights = [1, 2, 3, 4, 5]
weighted_mean_value = calculate_weighted_mean(values, weights)

print("Weighted Mean:", weighted_mean_value)

"e. Function to calculate the weighted mean"
def calculate_weighted_mean(values, weights):
    weighted_sum = sum(value * weight for value, weight in zip(values, weights))
    total_weight = sum(weights)
    return weighted_sum / total_weight

# Example usage
values = [90, 95, 100, 105, 110]
weights = [1, 2, 3, 4, 5]
weighted_mean_value = calculate_weighted_mean(values, weights)

print("Weighted Mean:", weighted_mean_value)


"f.Find the Geometric Mean"

import math

def calculate_geometric_mean(numbers):
    product = math.prod(numbers)
    return product ** (1 / len(numbers))

# Example usage (using the first 10 positive numbers from the list)
geometric_mean_value = calculate_geometric_mean(int_list[:10])

print("Geometric Mean:", geometric_mean_value)


"g.Calculate the Harmonic Mean"

def calculate_harmonic_mean(numbers):
    return len(numbers) / sum(1 / number for number in numbers)

# Example usage (using the first 10 numbers from the list)
harmonic_mean_value = calculate_harmonic_mean(int_list[:10])

print("Harmonic Mean:", harmonic_mean_value)

"I.Determine the Midrange"

def calculate_midrange(numbers):
    return (min(numbers) + max(numbers)) / 2

midrange_value = calculate_midrange(int_list)

print("Midrange:", midrange_value)

"J.Find the Trimmed Mean"

import scipy.stats as stats

def calculate_trimmed_mean(numbers, proportion_to_cut):
    return stats.trim_mean(numbers, proportion_to_cut)

# Example usage
trimmed_mean_value = calculate_trimmed_mean(int_list, 0.1)

print("Trimmed Mean (10%):", trimmed_mean_value)
# Out:
# Generated List: [114, 97, 102, 127, 114, 90, 129, 101, 95, 110, 90, 115, 103, 115, 103, 108, 99, 130, 106, 126, 114, 116, 101, 113, 92, 103, 129, 105, 127, 120, 120, 119, 102, 130, 127, 96, 120, 127, 125, 130, 103, 122, 104, 95, 111, 124, 102, 115, 114, 107, 103, 122, 106, 112, 100, 95, 112, 90, 92, 109, 92, 123, 102, 97, 128, 91, 94, 126, 112, 107, 97, 118, 97, 94, 104, 116, 107, 105, 90, 95, 99, 96, 120, 122, 98, 128, 103, 104, 115, 121, 129, 91, 127, 100, 91, 106, 129, 95, 117, 124]
# Mean: 109.38
# Median: 107.0
# Mode: 103
# Weighted Mean: 103.33333333333333
# Weighted Mean: 103.33333333333333
# Geometric Mean: 107.18290443830138
# Harmonic Mean: 106.48227980280407
# Midrange: 110.0
# Trimmed Mean (10%): 109.25

# %%
" 2. Generate a list of 500 integers containing values between 200 to 300 and store it in the variable `int_list2`.After generating the list, find the following"

"a.Generate the List of 500 Integers"

import random

int_list2 = [random.randint(200, 300) for _ in range(500)]
print("Generated List:", int_list2)

"b.Frequency & Gaussian Distribution"

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

plt.hist(int_list2, bins=15, density=True, alpha=0.6, color='g')

mu, std = np.mean(int_list2), np.std(int_list2)
xmin, xmax = min(int_list2), max(int_list2)
x = np.linspace(xmin, xmax, 100)
p = np.exp(-((x - mu) ** 2) / (2 * std ** 2)) / (std * np.sqrt(2 * np.pi))

plt.plot(x, p, 'k', linewidth=2)
plt.title('Frequency & Gaussian Distribution')
plt.show()

"c.Frequency Smoothened KDE Plot"

sns.kdeplot(int_list2, shade=True, color="r")
plt.title('Frequency Smoothened KDE Plot')
plt.show()

"d.Gaussian Distribution & Smoothened KDE Plot"

sns.kdeplot(int_list2, shade=True, color="r")
plt.plot(x, p, 'k', linewidth=2)
plt.title('Gaussian Distribution & Smoothened KDE Plot')
plt.show()

"e.Calculate the Range"

def calculate_range(numbers):
    return max(numbers) - min(numbers)

range_value = calculate_range(int_list2)
print("Range:", range_value)

"f.Calculate Variance and Standard Deviation"

def calculate_variance(numbers):
    mean = np.mean(numbers)
    return sum((x - mean) ** 2 for x in numbers) / len(numbers)

def calculate_std_deviation(numbers):
    return np.sqrt(calculate_variance(numbers))

variance_value = calculate_variance(int_list2)
std_deviation_value = calculate_std_deviation(int_list2)

print("Variance:", variance_value)
print("Standard Deviation:", std_deviation_value)

"g.Compute the Interquartile Range (IQR)"

def calculate_iqr(numbers):
    q75, q25 = np.percentile(numbers, [75, 25])
    return q75 - q25

iqr_value = calculate_iqr(int_list2)
print("Interquartile Range (IQR):", iqr_value)

"h.Calculate the Coefficient of Variation"

def calculate_coefficient_of_variation(numbers):
    mean = np.mean(numbers)
    std_dev = calculate_std_deviation(numbers)
    return std_dev / mean

cv_value = calculate_coefficient_of_variation(int_list2)
print("Coefficient of Variation:", cv_value)

"i.Calculate the Mean Absolute Deviation (MAD)"

def calculate_mad(numbers):
    mean = np.mean(numbers)
    return np.mean([abs(x - mean) for x in numbers])

mad_value = calculate_mad(int_list2)
print("Mean Absolute Deviation (MAD):", mad_value)

"j.Calculate the Quartile Deviation"

def calculate_quartile_deviation(numbers):
    q75, q25 = np.percentile(numbers, [75, 25])
    return (q75 - q25) / 2

quartile_deviation_value = calculate_quartile_deviation(int_list2)
print("Quartile Deviation:", quartile_deviation_value)

"k.Calculate the Range-Based Coefficient of Dispersion"

def calculate_coefficient_of_dispersion(numbers):
    return (max(numbers) - min(numbers)) / (max(numbers) + min(numbers))

coefficient_of_dispersion_value = calculate_coefficient_of_dispersion(int_list2)
print("Range-Based Coefficient of Dispersion:", coefficient_of_dispersion_value)
# Out:
# Generated List: [269, 298, 280, 214, 222, 246, 275, 248, 287, 228, 231, 260, 237, 222, 222, 238, 210, 218, 246, 263, 243, 243, 233, 232, 220, 251, 221, 284, 263, 219, 273, 285, 226, 291, 239, 272, 224, 242, 273, 299, 242, 211, 290, 244, 243, 259, 251, 298, 238, 239, 233, 282, 213, 236, 296, 207, 253, 288, 261, 282, 213, 228, 285, 239, 267, 208, 244, 213, 248, 232, 269, 257, 216, 268, 288, 258, 226, 299, 269, 200, 264, 219, 283, 210, 282, 288, 244, 293, 222, 278, 235, 292, 235, 252, 288, 261, 268, 261, 300, 231, 267, 216, 297, 247, 221, 212, 202, 282, 294, 272, 209, 246, 219, 272, 235, 273, 201, 272, 252, 250, 280, 255, 211, 211, 203, 270, 270, 237, 232, 200, 250, 292, 254, 254, 204, 223, 242, 263, 278, 267, 290, 204, 259, 238, 290, 210, 241, 244, 233, 239, 291, 209, 248, 288, 285, 281, 202, 231, 203, 252, 219, 208, 217, 269, 223, 229, 245, 265, 272, 254, 219, 298, 298, 261, 297, 224, 277, 221, 214, 211, 205, 210, 214, 251, 247, 226, 274, 231, 273, 229, 212, 224, 221, 241, 267, 277, 2
# ...

# %%
"3. Write a Python class representing a discrete random variable with methods to calculate its expected value and variance."

class DiscreteRandomVariable:
    def __init__(self, values, probabilities):
        
        self.values = values
        self.probabilities = probabilities

    def expected_value(self):
       
        return sum(value * prob for value, prob in zip(self.values, self.probabilities))

    def variance(self):
       
        mean = self.expected_value()
        return sum(prob * (value - mean) ** 2 for value, prob in zip(self.values, self.probabilities))


# Example usage
values = [1, 2, 3, 4, 5]
probabilities = [0.1, 0.2, 0.3, 0.2, 0.2]

rv = DiscreteRandomVariable(values, probabilities)
print("Expected Value:", rv.expected_value())
print("Variance:", rv.variance())
# Out:
# Expected Value: 3.2
# Variance: 1.56

# %%
"4.Implement a program to simulate the rolling of a fair six-sided die and calculate the expected value and variance of the outcomes."

import random
import numpy as np

def roll_die():
    return random.randint(1, 6)

n_rolls = 1000
rolls = [roll_die() for _ in range(n_rolls)]

def calculate_expected_value(rolls):
    return np.mean(rolls)

def calculate_variance(rolls):
    return np.var(rolls)

expected_value = calculate_expected_value(rolls)
variance_value = calculate_variance(rolls)

print("Simulated Rolls:", rolls[:20], "...")
print("Expected Value:", expected_value)
print("Variance:", variance_value)
# Out:
# Simulated Rolls: [4, 1, 3, 5, 3, 3, 1, 4, 4, 5, 1, 3, 4, 4, 6, 1, 2, 1, 2, 5] ...
# Expected Value: 3.473
# Variance: 2.8592709999999997

# %%
"5. Create a Python function to generate random samples from a given probability distribution (e.g.,binomial, Poisson) and calculate their mean and variance."

import numpy as np

def generate_samples(distribution, params, size=1000):
    
    if distribution == 'binomial':
        n = params.get('n', 1)
        p = params.get('p', 0.5)
        samples = np.random.binomial(n, p, size)
    elif distribution == 'poisson':
        lam = params.get('lam', 1)
        samples = np.random.poisson(lam, size)
    else:
        raise ValueError("Unsupported distribution. Use 'binomial' or 'poisson'.")
    
    mean = np.mean(samples)
    variance = np.var(samples)
    
    return mean, variance

# Example usage for binomial distribution
binomial_params = {'n': 10, 'p': 0.5}
binomial_mean, binomial_variance = generate_samples('binomial', binomial_params)
print(f"Binomial Distribution - Mean: {binomial_mean}, Variance: {binomial_variance}")

# Example usage for poisson distribution
poisson_params = {'lam': 3}
poisson_mean, poisson_variance = generate_samples('poisson', poisson_params)
print(f"Poisson Distribution - Mean: {poisson_mean}, Variance: {poisson_variance}")
# Out:
# Binomial Distribution - Mean: 4.976, Variance: 2.479424
# Poisson Distribution - Mean: 3.057, Variance: 3.0497509999999997

# %%
"6.Write a Python script to generate random numbers from a Gaussian (normal) distribution and compute the mean, variance, and standard deviation of the samples."

import numpy as np

def generate_gaussian_samples(mean, std_dev, num_samples):
    
    return np.random.normal(loc=mean, scale=std_dev, size=num_samples)

def compute_statistics(samples):
   
    mean = np.mean(samples)
    variance = np.var(samples)
    std_dev = np.std(samples)
    return {
        "mean": mean,
        "variance": variance,
        "standard_deviation": std_dev
    }

def main():
    # Parameters
    mean = 0  # Mean of the Gaussian distribution
    std_dev = 1  # Standard deviation of the Gaussian distribution
    num_samples = 1000  # Number of samples

    # Generate samples
    samples = generate_gaussian_samples(mean, std_dev, num_samples)

    # Compute statistics
    stats = compute_statistics(samples)

    # Print results
    print("Generated Gaussian Samples Statistics:")
    print(f"Mean: {stats['mean']}")
    print(f"Variance: {stats['variance']}")
    print(f"Standard Deviation: {stats['standard_deviation']}")

if __name__ == "__main__":
    main()
# Out:
# Generated Gaussian Samples Statistics:
# Mean: 0.005383927129576882
# Variance: 1.003745852241813
# Standard Deviation: 1.0018711754720828

# %%
"7.Use seaborn library to load tips dataset. Find the following from the dataset for the columns total_bill and tip`:"

import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import skew, pearsonr

# Load the tips dataset
tips = sns.load_dataset("tips")

# (i) Function to calculate skewness
def calculate_skewness(column):
    return skew(column)

# (ii) Program to determine skewness type
def skewness_type(column):
    skewness_value = calculate_skewness(column)
    if skewness_value > 0:
        return "Positive Skewness"
    elif skewness_value < 0:
        return "Negative Skewness"
    else:
        return "Approximately Symmetric"

# (iii) Function to calculate covariance between two columns
def calculate_covariance(column1, column2):
    return np.cov(column1, column2)[0, 1]

# (iv) Program to calculate Pearson correlation coefficient
def calculate_pearson_correlation(column1, column2):
    corr, _ = pearsonr(column1, column2)
    return corr

# (v) Script to visualize correlation with scatter plot
def visualize_correlation(column1, column2, label1, label2):
    plt.figure(figsize=(8, 6))
    plt.scatter(column1, column2, alpha=0.7, color='blue')
    plt.title(f'Scatter Plot of {label1} vs {label2}')
    plt.xlabel(label1)
    plt.ylabel(label2)
    plt.grid()
    plt.show()

# Columns to analyze
total_bill = tips['total_bill']
tip = tips['tip']

# Outputs
print("Skewness of total_bill:", calculate_skewness(total_bill))
print("Skewness type of total_bill:", skewness_type(total_bill))
print("Skewness of tip:", calculate_skewness(tip))
print("Skewness type of tip:", skewness_type(tip))

print("Covariance between total_bill and tip:", calculate_covariance(total_bill, tip))
print("Pearson correlation coefficient between total_bill and tip:", calculate_pearson_correlation(total_bill, tip))

# Visualize the correlation
visualize_correlation(total_bill, tip, "Total Bill", "Tip")
# Out:
# Skewness of total_bill: 1.1262346334818638
# Skewness type of total_bill: Positive Skewness
# Skewness of tip: 1.4564266884221506
# Skewness type of tip: Positive Skewness
# Covariance between total_bill and tip: 8.323501629224854
# Pearson correlation coefficient between total_bill and tip: 0.6757341092113645

# %%
"8. Write a Python function to calculate the probability density function (PDF) of a continuous random variable for a given normal distribution."

import math

def normal_pdf(x, mean, std_dev):
   
    coefficient = 1 / (std_dev * math.sqrt(2 * math.pi))
    exponent = math.exp(-((x - mean) ** 2) / (2 * std_dev ** 2))
    return coefficient * exponent

# Example usage
mean = 0  # Mean of the distribution
std_dev = 1  # Standard deviation of the distribution
x = 1  # Value at which to calculate the PDF

pdf_value = normal_pdf(x, mean, std_dev)
print(f"The PDF value at x = {x} for N({mean}, {std_dev**2}) is {pdf_value}")
# Out:
# The PDF value at x = 1 for N(0, 1) is 0.24197072451914337

# %%
"9.Create a program to calculate the cumulative distribution function (CDF) of exponential distribution."

import math

def exponential_cdf(x, rate):
    
    if x < 0:
        return 0.0  # The CDF is 0 for x < 0 in an exponential distribution
    return 1 - math.exp(-rate * x)

# Example usage
rate = 2.0  # Lambda (rate parameter)
x = 1.5  # Value at which to calculate the CDF

cdf_value = exponential_cdf(x, rate)
print(f"The CDF value at x = {x} for an exponential distribution with rate = {rate} is {cdf_value}")
# Out:
# The CDF value at x = 1.5 for an exponential distribution with rate = 2.0 is 0.950212931632136

# %%
"10.Write a Python function to calculate the probability mass function (PMF) of Poisson distribution"

import math

def poisson_pmf(k, rate):
    
    if k < 0:
        return 0.0  # The PMF is 0 for negative values of k
    return (math.exp(-rate) * (rate ** k)) / math.factorial(k)

# Example usage
rate = 3.0  # Lambda (average rate of occurrences)
k = 5  # Number of events

pmf_value = poisson_pmf(k, rate)
print(f"The PMF value at k = {k} for a Poisson distribution with rate = {rate} is {pmf_value}")
# Out:
# The PMF value at k = 5 for a Poisson distribution with rate = 3.0 is 0.10081881344492448

# %%
"11. A company wants to test if a new website layout leads to a higher conversion rate (percentage of visitors who make a purchase). They collect data from the old and new layouts to compare."

import numpy as np
from scipy.stats import norm

old_layout = np.array([1] * 50 + [0] * 950)
new_layout = np.array([1] * 70 + [0] * 930)

n_old = len(old_layout)
n_new = len(new_layout)

p_old = np.mean(old_layout)
p_new = np.mean(new_layout)

p_pool = (np.sum(old_layout) + np.sum(new_layout)) / (n_old + n_new)

z_stat = (p_new - p_old) / np.sqrt(p_pool * (1 - p_pool) * (1/n_old + 1/n_new))

p_value = 1 - norm.cdf(z_stat)

alpha = 0.05

print(f"Old layout conversion rate: {p_old:.4f}")
print(f"New layout conversion rate: {p_new:.4f}")
print(f"Z-statistic: {z_stat:.4f}")
print(f"P-value: {p_value:.4f}")

if p_value < alpha:
    print("Reject the null hypothesis: The new layout leads to a higher conversion rate.")
else:
    print("Fail to reject the null hypothesis: No significant difference in conversion rates.")
# Out:
# Old layout conversion rate: 0.0500
# New layout conversion rate: 0.0700
# Z-statistic: 1.8831
# P-value: 0.0298
# Reject the null hypothesis: The new layout leads to a higher conversion rate.

# %%
"12.A tutoring service claims that its program improves students' exam scores. A sample of students who participated in the program was taken, and their scores before and after the program were recorded."

import numpy as np
from scipy.stats import norm

before_program = np.array([75, 80, 85, 70, 90, 78, 92, 88, 82, 87])
after_program = np.array([80, 85, 90, 80, 92, 80, 95, 90, 85, 88])

differences = after_program - before_program

mean_diff = np.mean(differences)
std_diff = np.std(differences, ddof=1)  # Sample standard deviation
n = len(differences)

z = mean_diff / (std_diff / np.sqrt(n))

p_value = 1 - norm.cdf(z)

print(f"Mean Difference: {mean_diff:.2f}")
print(f"Standard Deviation of Differences: {std_diff:.2f}")
print(f"Z-Statistic: {z:.2f}")
print(f"P-Value: {p_value:.4f}")

alpha = 0.05  
if p_value < alpha:
    print("Reject the null hypothesis: The tutoring program improves scores.")
else:
    print("Fail to reject the null hypothesis: No significant evidence that the program improves scores.")
# Out:
# Mean Difference: 3.80
# Standard Deviation of Differences: 2.62
# Z-Statistic: 4.59
# P-Value: 0.0000
# Reject the null hypothesis: The tutoring program improves scores.

# %%
"13.A pharmaceutical company wants to determine if a new drug is effective in reducing blood pressure. They conduct a study and record blood pressure measurements before and after administering the drug."

import numpy as np
import scipy.stats as stats

before_drug = np.array([145, 150, 140, 135, 155, 160, 152, 148, 130, 138])
after_drug = np.array([130, 140, 132, 128, 145, 148, 138, 136, 125, 130])

differences = before_drug - after_drug

mean_difference = np.mean(differences)
std_difference = np.std(differences, ddof=1)  
n = len(differences)

z_statistic = mean_difference / (std_difference / np.sqrt(n))

p_value = 2 * (1 - stats.norm.cdf(abs(z_statistic)))

print(f"Z-statistic: {z_statistic:.4f}")
print(f"P-value: {p_value:.4f}")

alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: The drug has a significant effect on blood pressure.")
else:
    print("Fail to reject the null hypothesis: The drug does not have a significant effect on blood pressure.")
# Out:
# Z-statistic: 10.0499
# P-value: 0.0000
# Reject the null hypothesis: The drug has a significant effect on blood pressure.

# %%
"14.A customer service department claims that their average response time is less than 5 minutes. A sample of recent customer interactions was taken, and the response times were recorded."

import numpy as np
from scipy import stats

# Generate the array of response times
response_times = np.array([4.3, 3.8, 5.1, 4.9, 4.7, 4.2, 5.2, 4.5, 4.6, 4.4])

# Print the response times
print("Response Times:", response_times)

# Hypothesized population mean (claimed response time)
mu = 5

# Sample mean
sample_mean = np.mean(response_times)

# Sample standard deviation
sample_std = np.std(response_times, ddof=1)

# Sample size
n = len(response_times)

# Standard error of the mean
se = sample_std / np.sqrt(n)

# Calculate the z-score
z_score = (sample_mean - mu) / se

# Calculate the p-value
p_value = stats.norm.cdf(z_score)

# Print the results
print("Sample Mean:", sample_mean)
print("Sample Standard Deviation:", sample_std)
print("Sample Size:", n)
print("Z-Score:", z_score)
print("P-Value:", p_value)
# Out:
# Response Times: [4.3 3.8 5.1 4.9 4.7 4.2 5.2 4.5 4.6 4.4]
# Sample Mean: 4.57
# Sample Standard Deviation: 0.4270050741306634
# Sample Size: 10
# Z-Score: -3.184457226042963
# P-Value: 0.0007251287113068958

# %%
"15.A company is testing two different website layouts to see which one leads to higher click-through rates. Write a Python function to perform an A/B test analysis, including calculating the t-statistic, degrees of freedom, and p-value"

import numpy as np
from scipy import stats

layout_a_clicks = [28, 32, 33, 29, 31, 34, 30, 35, 36, 37]
layout_b_clicks = [40, 41, 38, 42, 39, 44, 43, 41, 45, 47]

def ab_test(layout_a, layout_b):
    mean_a = np.mean(layout_a)
    mean_b = np.mean(layout_b)
    std_a = np.std(layout_a, ddof=1)
    std_b = np.std(layout_b, ddof=1)
    
    t_statistic, p_value = stats.ttest_ind(layout_a, layout_b, equal_var=False)
    
    n_a = len(layout_a)
    n_b = len(layout_b)
    df = ((std_a**2 / n_a) + (std_b**2 / n_b))**2 / (((std_a**2 / n_a)**2 / (n_a - 1)) + ((std_b**2 / n_b)**2 / (n_b - 1)))
    
    return t_statistic, df, p_value

t_statistic, df, p_value = ab_test(layout_a_clicks, layout_b_clicks)

print("T-Statistic:", t_statistic)
print("Degrees of Freedom:", df)
print("P-Value:", p_value)
# Out:
# T-Statistic: -7.298102156175069
# Degrees of Freedom: 17.879871863320876
# P-Value: 9.19659607078939e-07

# %%
"16.A pharmaceutical company wants to determine if a new drug is more effective than an existing drug in reducing cholesterol levels. Create a program to analyze the clinical trial data and calculate the tstatistic and p-value for the treatment effect"

import numpy as np
from scipy import stats

existing_drug_levels = [180, 182, 175, 185, 178, 176, 172, 184, 179, 183]
new_drug_levels = [170, 172, 165, 168, 175, 173, 170, 178, 172, 176]

def t_test(existing_drug, new_drug):
    mean_existing = np.mean(existing_drug)
    mean_new = np.mean(new_drug)
    std_existing = np.std(existing_drug, ddof=1)
    std_new = np.std(new_drug, ddof=1)
    
    t_statistic, p_value = stats.ttest_ind(existing_drug, new_drug, equal_var=False)
    
    n_existing = len(existing_drug)
    n_new = len(new_drug)
    df = ((std_existing**2 / n_existing) + (std_new**2 / n_new))**2 / (((std_existing**2 / n_existing)**2 / (n_existing - 1)) + ((std_new**2 / n_new)**2 / (n_new - 1)))
    
    return t_statistic, df, p_value

t_statistic, df, p_value = t_test(existing_drug_levels, new_drug_levels)

print("T-Statistic:", t_statistic)
print("Degrees of Freedom:", df)
print("P-Value:", p_value)
# Out:
# T-Statistic: 4.140480986208659
# Degrees of Freedom: 17.866770765582338
# P-Value: 0.0006229228945469329

# %%
"17.A school district introduces an educational intervention program to improve math scores. Write a Python function to analyze pre- and post-intervention test scores, calculating the t-statistic and p-value to determine if the intervention had a significant impact."

import numpy as np
from scipy import stats

pre_intervention_scores = [80, 85, 90, 75, 88, 82, 92, 78, 85, 87]
post_intervention_scores = [90, 92, 88, 92, 95, 91, 96, 93, 89, 93]

def paired_t_test(pre_scores, post_scores):
    t_statistic, p_value = stats.ttest_rel(pre_scores, post_scores)
    return t_statistic, p_value

t_statistic, p_value = paired_t_test(pre_intervention_scores, post_intervention_scores)

print("T-Statistic:", t_statistic)
print("P-Value:", p_value)
# Out:
# T-Statistic: -4.42840883965761
# P-Value: 0.0016509548165795493

# %%
"18.An HR department wants to investigate if there's a gender-based salary gap within the company. Develop a program to analyze salary data, calculate the t-statistic, and determine if there's a statistically significant difference between the average salaries of male and female employees."

import numpy as np
from scipy import stats

np.random.seed(0)  

male_salaries = np.random.normal(loc=50000, scale=10000, size=20)
female_salaries = np.random.normal(loc=55000, scale=9000, size=20)

def gender_salary_gap_test(male_salaries, female_salaries):
    mean_male = np.mean(male_salaries)
    mean_female = np.mean(female_salaries)
    std_male = np.std(male_salaries, ddof=1)
    std_female = np.std(female_salaries, ddof=1)
    
    t_statistic, p_value = stats.ttest_ind(male_salaries, female_salaries, equal_var=False)
    
    n_male = len(male_salaries)
    n_female = len(female_salaries)
    df = ((std_male**2 / n_male) + (std_female**2 / n_female))**2 / (((std_male**2 / n_male)**2 / (n_male - 1)) + ((std_female**2 / n_female)**2 / (n_female - 1)))
    
    return t_statistic, df, p_value

t_statistic, df, p_value = gender_salary_gap_test(male_salaries, female_salaries)

print("Male Salaries:", male_salaries)
print("Female Salaries:", female_salaries)
print("T-Statistic:", t_statistic)
print("Degrees of Freedom:", df)
print("P-Value:", p_value)
# Out:
# Male Salaries: [67640.52345968 54001.57208367 59787.37984106 72408.93199201
#  68675.5799015  40227.22120124 59500.88417526 48486.42791702
#  48967.81148206 54105.98501938 51440.43571161 64542.73506963
#  57610.37725147 51216.75016493 54438.63232745 53336.74327374
#  64940.79073158 47948.41736234 53130.67701651 41459.04260698]
# Female Salaries: [32023.09165749 60882.56735896 62779.92578974 48320.51481634
#  75427.79161589 41910.70892861 55411.82665571 53315.34534977
#  68795.01292923 68224.2289291  56394.52683127 58403.46267642
#  47009.92827133 37172.83178598 51868.79065606 56407.14072194
#  66072.61612655 65821.41863906 51514.05864333 52279.27524482]
# T-Statistic: 0.061142089696313844
# Degrees of Freedom: 36.166783312917644
# P-Value: 0.9515826849267927

# %%
"19.A manufacturer produces two different versions of a product and wants to compare their quality scores. Create a Python function to analyze quality assessment data, calculate the t-statistic, and decide whether there's a significant difference in quality between the two versions."

import numpy as np
from scipy import stats

version1_scores = [85, 88, 82, 89, 87, 84, 90, 88, 85, 86, 91, 83, 87, 84, 89, 86, 84, 88, 85, 86, 89, 90, 87, 88, 85]
version2_scores = [80, 78, 83, 81, 79, 82, 76, 80, 78, 81, 77, 82, 80, 79, 82, 79, 80, 81, 79, 82, 79, 78, 80, 81, 82]

def quality_comparison_test(version1, version2):
    mean_v1 = np.mean(version1)
    mean_v2 = np.mean(version2)
    std_v1 = np.std(version1, ddof=1)
    std_v2 = np.std(version2, ddof=1)
    
    t_statistic, p_value = stats.ttest_ind(version1, version2, equal_var=False)
    
    n_v1 = len(version1)
    n_v2 = len(version2)
    df = ((std_v1**2 / n_v1) + (std_v2**2 / n_v2))**2 / (((std_v1**2 / n_v1)**2 / (n_v1 - 1)) + ((std_v2**2 / n_v2)**2 / (n_v2 - 1)))
    
    return t_statistic, df, p_value

t_statistic, df, p_value = quality_comparison_test(version1_scores, version2_scores)

print("Version 1 Scores:", version1_scores)
print("Version 2 Scores:", version2_scores)
print("T-Statistic:", t_statistic)
print("Degrees of Freedom:", df)
print("P-Value:", p_value)
# Out:
# Version 1 Scores: [85, 88, 82, 89, 87, 84, 90, 88, 85, 86, 91, 83, 87, 84, 89, 86, 84, 88, 85, 86, 89, 90, 87, 88, 85]
# Version 2 Scores: [80, 78, 83, 81, 79, 82, 76, 80, 78, 81, 77, 82, 80, 79, 82, 79, 80, 81, 79, 82, 79, 78, 80, 81, 82]
# T-Statistic: 11.325830417646698
# Degrees of Freedom: 44.47061033283036
# P-Value: 1.078754084378157e-14

# %%
"20. A restaurant chain collects customer satisfaction scores for two different branches. Write a program to analyze the scores, calculate the t-statistic, and determine if there's a statistically significant difference in customer satisfaction between the branches"

import numpy as np
from scipy import stats

branch_a_scores = [4, 5, 3, 4, 5, 4, 5, 3, 4, 4, 5, 4, 4, 3, 4, 5, 5, 4, 3, 4, 5, 4, 3, 5, 4, 4, 5, 3, 4, 5, 4]
branch_b_scores = [3, 4, 2, 3, 4, 3, 4, 2, 3, 3, 4, 3, 3, 2, 3, 4, 4, 3, 2, 3, 4, 3, 2, 4, 3, 3, 4, 2, 3, 4, 3]

def satisfaction_comparison_test(branch_a, branch_b):
    mean_a = np.mean(branch_a)
    mean_b = np.mean(branch_b)
    std_a = np.std(branch_a, ddof=1)
    std_b = np.std(branch_b, ddof=1)
    
    t_statistic, p_value = stats.ttest_ind(branch_a, branch_b, equal_var=False)
    
    n_a = len(branch_a)
    n_b = len(branch_b)
    df = ((std_a**2 / n_a) + (std_b**2 / n_b))**2 / (((std_a**2 / n_a)**2 / (n_a - 1)) + ((std_b**2 / n_b)**2 / (n_b - 1)))
    
    return t_statistic, df, p_value

t_statistic, df, p_value = satisfaction_comparison_test(branch_a_scores, branch_b_scores)

print("Branch A Scores:", branch_a_scores)
print("Branch B Scores:", branch_b_scores)
print("T-Statistic:", t_statistic)
print("Degrees of Freedom:", df)
print("P-Value:", p_value)
# Out:
# Branch A Scores: [4, 5, 3, 4, 5, 4, 5, 3, 4, 4, 5, 4, 4, 3, 4, 5, 5, 4, 3, 4, 5, 4, 3, 5, 4, 4, 5, 3, 4, 5, 4]
# Branch B Scores: [3, 4, 2, 3, 4, 3, 4, 2, 3, 3, 4, 3, 3, 2, 3, 4, 4, 3, 2, 3, 4, 3, 2, 4, 3, 3, 4, 2, 3, 4, 3]
# T-Statistic: 5.480077554195743
# Degrees of Freedom: 60.0
# P-Value: 8.895290509945657e-07

# %%
"21. A political analyst wants to determine if there is a significant association between age groups and voter preferences (Candidate A or Candidate B). They collect data from a sample of 500 voters and classify them into different age groups and candidate preferences. Perform a Chi-Square test to determine if there is a significant association between age groups and voter preferences."

import numpy as np
import pandas as pd
from scipy.stats import chi2_contingency

np.random.seed(0)

age_groups = np.random.choice(['18-30', '31-50', '51+'], size=500)
voter_preferences = np.random.choice(['Candidate A', 'Candidate B'], size=500)

data = pd.DataFrame({'Age Group': age_groups, 'Voter Preference': voter_preferences})

print(data.head())

contingency_table = pd.crosstab(data['Age Group'], data['Voter Preference'])

chi2, p, dof, expected = chi2_contingency(contingency_table)

print("Contingency Table:")
print(contingency_table)
print("\nChi-Square Statistic:", chi2)
print("Degrees of Freedom:", dof)
print("P-Value:", p)
# Out:
#   Age Group Voter Preference
# 0     18-30      Candidate B
# 1     31-50      Candidate A
# 2     18-30      Candidate B
# 3     31-50      Candidate B
# 4     31-50      Candidate A
# Contingency Table:
# Voter Preference  Candidate A  Candidate B
# Age Group
# 18-30                      95           87
# 31-50                      87           82
# 51+                        84           65
#
# Chi-Square Statistic: 0.8779923945254768
# Degrees of Freedom: 2
# P-Value: 0.6446832311860852

# %%
"22.. A company conducted a customer satisfaction survey to determine if there is a significant relationship between product satisfaction levels (Satisfied, Neutral, Dissatisfied) and the region where customers are located (East, West, North, South). The survey data is summarized in a contingency table. Conduct a ChiSquare test to determine if there is a significant relationship between product satisfaction levels and customer regions "

import numpy as np
from scipy.stats import chi2_contingency

data = np.array([[50, 30, 40, 20], [30, 40, 30, 50], [20, 30, 40, 30]])

chi2, p, dof, expected = chi2_contingency(data)

print("Contingency Table:")
print(data)
print("\nChi-Square Statistic:", chi2)
print("Degrees of Freedom:", dof)
print("P-Value:", p)
print("\nExpected Frequencies:")
print(expected)
# Out:
# Contingency Table:
# [[50 30 40 20]
#  [30 40 30 50]
#  [20 30 40 30]]
#
# Chi-Square Statistic: 27.777056277056275
# Degrees of Freedom: 6
# P-Value: 0.00010349448486004387
#
# Expected Frequencies:
# [[34.14634146 34.14634146 37.56097561 34.14634146]
#  [36.58536585 36.58536585 40.24390244 36.58536585]
#  [29.26829268 29.26829268 32.19512195 29.26829268]]

# %%
"23.A company implemented an employee training program to improve job performance (Effective, Neutral, Ineffective). After the training, they collected data from a sample of employees and classified them based on their job performance before and after the training. Perform a Chi-Square test to determine if there is a significant difference between job performance levels before and after the training "

import numpy as np
from scipy.stats import chi2_contingency

data = np.array([[50, 30, 20], [30, 40, 30], [20, 30, 40]])

chi2, p, dof, expected = chi2_contingency(data)

print("Contingency Table:")
print(data)
print("\nChi-Square Statistic:", chi2)
print("Degrees of Freedom:", dof)
print("P-Value:", p)
print("\nExpected Frequencies:")
print(expected)
# Out:
# Contingency Table:
# [[50 30 20]
#  [30 40 30]
#  [20 30 40]]
#
# Chi-Square Statistic: 22.161728395061726
# Degrees of Freedom: 4
# P-Value: 0.00018609719479882554
#
# Expected Frequencies:
# [[34.48275862 34.48275862 31.03448276]
#  [34.48275862 34.48275862 31.03448276]
#  [31.03448276 31.03448276 27.93103448]]

# %%
"24. A company produces three different versions of a product: Standard, Premium, and Deluxe. The company wants to determine if there is a significant difference in customer satisfaction scores among the three product versions. They conducted a survey and collected customer satisfaction scores for each version from a random sample of customers. Perform an ANOVA test to determine if there is a significant difference in  ustomer satisfaction scores."

import scipy.stats as stats

standard_scores = [80, 85, 90, 78, 88, 82, 92, 78, 85, 87]
premium_scores = [90, 92, 88, 92, 95, 91, 96, 93, 89, 93]
deluxe_scores = [95, 98, 92, 97, 96, 94, 98, 97, 92, 99]

f_statistic, p_value = stats.f_oneway(standard_scores, premium_scores, deluxe_scores)

print("F-Statistic:", f_statistic)
print("P-Value:", p_value)
# Out:
# F-Statistic: 27.03556231003039
# P-Value: 3.578632885734896e-07
